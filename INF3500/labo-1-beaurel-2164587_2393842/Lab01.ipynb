# %%
from pynq import MMIO

demo = MMIO(0x41200000, 0x10)

# Test écriture du code barre, laissez 1 seule ligne uncommentée

# Test code barre vide --> Led Bleu
demo.write(0x0, 0)

# Test code barre 0000 0000 0000 0000 0000 0000 0000 0001 --> Led Vert
# demo.write(0x0, 1)

# Test code barre 0000 0000 0000 0000 0000 0000 0000 0011 --> Led Rouge + Led du secteur 1 
# demo.write(0x0, 3)

# Test code barre 0000 0000 0000 0000 0000 0001 1000 0000 --> Led Rouge + Led du secteur 1
# demo.write(0x0, 384)

# Test code barre 0000 0000 0000 0000 0000 0011 0000 0000 --> Led Rouge + Led du secteur 2
# demo.write(0x0, 768)

# Test code barre 0000 0000 0000 0000 0000 0011 0000 0011 --> Led Rouge + Led du secteur 1
# demo.write(0x0, 771)

# Test code barre 0000 0001 0010 1000 1010 1001 0100 0100 --> Led Vert
# demo.write(0x0, 19441988)

# Test code barre 0000 0011 0000 0000 0000 0000 0000 0000 --> Led Rouge + Led du secteur 4
# demo.write(0x0, 50331648)
